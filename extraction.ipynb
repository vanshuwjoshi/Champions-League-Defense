# %%
import requests
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")

# %%
seasons = []
first = 1992
while first <= 2023:
    year = str(first) + "-" + str(first + 1)
    first = first + 1
    seasons.append(year)

# %%
url = "https://fbref.com/en/comps/8/1996-1997/schedule/1996-1997-Champions-League-Scores-and-Fixtures"

# %%
html = requests.get(url).content
df_list = pd.read_html(html)
league_table = df_list[0]

# %%
league_table[["Round", "Home", "Score", "Away"]]
# Out:
#           Round                Home Score                Away
# 0   Group stage         Juventus it   1–0  eng Manchester Utd
# 1   Group stage  Atlético Madrid es   4–0           ro Steaua
# 2   Group stage         Dortmund de   2–1      pl Widzew Łódź
# 3   Group stage       Rapid Wien at   1–1       tr Fenerbahçe
# 4   Group stage      Grasshopper ch   3–0         sct Rangers
# ..          ...                 ...   ...                 ...
# 62  Semi-finals             Ajax nl   1–2         it Juventus
# 63  Semi-finals         Dortmund de   1–0  eng Manchester Utd
# 64  Semi-finals  Manchester Utd eng   0–1         de Dortmund
# 65  Semi-finals         Juventus it   4–1             nl Ajax
# 66        Final         Dortmund de   3–1         it Juventus
#
# [67 rows x 4 columns]

# %%
def split_score(score):
    try:
        home_score = score[0]
        away_score = score[-1]
        return pd.Series([int(home_score), int(away_score)])
    except:
        return pd.Series([None, None])

# %%
def clean_data(df):
    df["Home"] = df["Home"].str[:-3]
    df["Away"] = df["Away"].str[3:]
    df[["Home_Score", "Away_Score"]] = df["Score"].apply(split_score)

    df["Winner_team"] = df.apply(
        lambda row: (
            row["Home"]
            if row["Home_Score"] > row["Away_Score"]
            else (row["Away"] if row["Away_Score"] > row["Home_Score"] else "Draw")
        ),
        axis=1,
    )
    df["Winner_Home_Away"] = df.apply(
        lambda row: (
            "Home"
            if row["Home_Score"] > row["Away_Score"]
            else ("Away" if row["Away_Score"] > row["Home_Score"] else "Draw")
        ),
        axis=1,
    )
    return df

# %%
X = league_table[["Round", "Home", "Score", "Away"]]
X.head()
# Out:
#          Round                Home Score                Away
# 0  Group stage         Juventus it   1–0  eng Manchester Utd
# 1  Group stage  Atlético Madrid es   4–0           ro Steaua
# 2  Group stage         Dortmund de   2–1      pl Widzew Łódź
# 3  Group stage       Rapid Wien at   1–1       tr Fenerbahçe
# 4  Group stage      Grasshopper ch   3–0         sct Rangers

# %%
X = X.dropna()

# %%
X = clean_data(X)
X.head()
# Out:
#          Round             Home Score             Away  Home_Score  \
# 0  Group stage         Juventus   1–0   Manchester Utd           1
# 1  Group stage  Atlético Madrid   4–0           Steaua           4
# 2  Group stage         Dortmund   2–1      Widzew Łódź           2
# 3  Group stage       Rapid Wien   1–1       Fenerbahçe           1
# 4  Group stage      Grasshopper   3–0          Rangers           3
#
#    Away_Score      Winner_team Winner_Home_Away
# 0           0         Juventus             Home
# 1           0  Atlético Madrid             Home
# 2           1         Dortmund             Home
# 3           1             Draw             Draw
# 4           0      Grasshopper             Home

# %%
def get_table(season):
    url = f"https://fbref.com/en/comps/8/{season}/schedule/{season}-Champions-League-Scores-and-Fixtures"
    try:
        html = requests.get(url).content
        df = pd.read_html(html)
        return df[0]
    except Exception as e:
        print(f"Error on {season}: {e}")
        pass


def select_cols(df):
    try:
        return df[["Round", "Home", "Score", "Away"]]
    except Exception as e:
        print(f"Error message: {e}")


def clean_data(df):
    try:
        df = df.dropna()
    except Exception as e:
        print(f"Error message: {e}")
        pass
    df.loc[:, "Home"] = df["Home"].str[:-3]
    df.loc[:, "Away"] = df["Away"].str[3:]
    df[["Home_Score", "Away_Score"]] = df["Score"].apply(split_score)

    df.loc[:, "Winner_team"] = df.apply(
        lambda row: (
            row["Home"]
            if row["Home_Score"] > row["Away_Score"]
            else (row["Away"] if row["Away_Score"] > row["Home_Score"] else "Draw")
        ),
        axis=1,
    )
    df.loc[:, "Winner_Home_Away"] = df.apply(
        lambda row: (
            "Home"
            if row["Home_Score"] > row["Away_Score"]
            else ("Away" if row["Away_Score"] > row["Home_Score"] else "Draw")
        ),
        axis=1,
    )
    return df


def save_csv(df, season):
    try:
        df.to_csv(f"./data/{season}.csv")
    except Exception as e:
        print(f"Error message: {e}")

# %%
Y = league_table[["Round", "Home", "Score", "Away"]]
Y.head()
# Out:
#          Round                Home Score                Away
# 0  Group stage         Juventus it   1–0  eng Manchester Utd
# 1  Group stage  Atlético Madrid es   4–0           ro Steaua
# 2  Group stage         Dortmund de   2–1      pl Widzew Łódź
# 3  Group stage       Rapid Wien at   1–1       tr Fenerbahçe
# 4  Group stage      Grasshopper ch   3–0         sct Rangers

# %%
Y = clean_data(Y)
Y.head()
# Out:
#          Round             Home Score             Away  Home_Score  \
# 0  Group stage         Juventus   1–0   Manchester Utd           1
# 1  Group stage  Atlético Madrid   4–0           Steaua           4
# 2  Group stage         Dortmund   2–1      Widzew Łódź           2
# 3  Group stage       Rapid Wien   1–1       Fenerbahçe           1
# 4  Group stage      Grasshopper   3–0          Rangers           3
#
#    Away_Score      Winner_team Winner_Home_Away
# 0           0         Juventus             Home
# 1           0  Atlético Madrid             Home
# 2           1         Dortmund             Home
# 3           1             Draw             Draw
# 4           0      Grasshopper             Home

# %%
save_csv(Y,"AHSD")

# %%
Y.to_csv("./data/data.csv")

# %%
for season in seasons:
    print(season)
    try:
        df = get_table(season=season)
        df = select_cols(df)
        df = clean_data(df)
        save_csv(df, season)
    except Exception as e:
        print(f"Error message: {e}")
        pass
# Out:
# 1992-1993
# Error on 1992-1993: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 1993-1994
# Error on 1993-1994: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 1994-1995
# Error on 1994-1995: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 1995-1996
# Error on 1995-1996: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 1996-1997
# Error on 1996-1997: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 1997-1998
# Error on 1997-1998: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 1998-1999
# Error on 1998-1999: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 1999-2000
# Error on 1999-2000: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2000-2001
# Error on 2000-2001: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2001-2002
# Error on 2001-2002: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2002-2003
# Error on 2002-2003: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2003-2004
# Error on 2003-2004: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2004-2005
# Error on 2004-2005: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2005-2006
# Error on 2005-2006: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2006-2007
# Error on 2006-2007: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2007-2008
# Error on 2007-2008: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2008-2009
# Error on 2008-2009: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2009-2010
# Error on 2009-2010: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2010-2011
# Error on 2010-2011: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2011-2012
# Error on 2011-2012: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2012-2013
# Error on 2012-2013: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2013-2014
# Error on 2013-2014: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2014-2015
# Error on 2014-2015: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2015-2016
# Error on 2015-2016: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2016-2017
# Error on 2016-2017: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2017-2018
# Error on 2017-2018: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2018-2019
# Error on 2018-2019: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2019-2020
# Error on 2019-2020: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2020-2021
# Error on 2020-2021: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2021-2022
# Error on 2021-2022: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2022-2023
# Error on 2022-2023: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
# 2023-2024
# Error on 2023-2024: No tables found
# Error message: 'NoneType' object is not subscriptable
# Error message: 'NoneType' object has no attribute 'dropna'
# Error message: 'NoneType' object is not subscriptable
